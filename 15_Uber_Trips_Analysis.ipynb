# %% [markdown]
# <a href="https://colab.research.google.com/github/sujith-645/devtern/blob/main/15_Uber_Trips_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # importing the necessary Python libraries and the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("uber-raw-data-jun14.csv")

# %%
data
# Out:
#                                 913  B02598
# 6/16/2014 4:16:00  40.7254 -74.0022  B02598
#                    40.7719 -73.9656  B02598
# 6/16/2014 4:18:00  40.7309 -73.9954  B02598
#                    40.8149 -73.9578  B02598
#                    40.7664 -73.9664  B02598
# ...                             ...     ...
# 6/30/2014 14:52:00 40.7488 -73.9872  B02598
#                    40.7526 -73.8887  B02598
#                    40.7857 -73.9782  B02598
#                    40.7612 -73.9713  B02598
#                    40.6560 -73.7813     NaN
#
# [112672 rows x 2 columns]

# %% [markdown]
# # prepare the data according to days and hours

# %%
data
# Out:
#                                 913  B02598
# 6/16/2014 4:16:00  40.7254 -74.0022  B02598
#                    40.7719 -73.9656  B02598
# 6/16/2014 4:18:00  40.7309 -73.9954  B02598
#                    40.8149 -73.9578  B02598
#                    40.7664 -73.9664  B02598
# ...                             ...     ...
# 6/30/2014 14:52:00 40.7488 -73.9872  B02598
#                    40.7526 -73.8887  B02598
#                    40.7857 -73.9782  B02598
#                    40.7612 -73.9713  B02598
#                    40.6560 -73.7813     NaN
#
# [112672 rows x 2 columns]

# %% [markdown]
# # look at each day to see on which day the Uber trips were highest

# %%
sns.set(rc={'figure.figsize':(15,13)})
sns.distplot(data["day"])

# %% [markdown]
# # analyse the Uber trips according to the hours

# %%
sns.distplot(data["hour"])

# %% [markdown]
# # analyse the Uber trips according to the weekdays

# %%
sns.distplot(data["weekdays"])

# %% [markdown]
# # look at the correlation of hours and weekdays

# %% [markdown]
# # plot the density of Uber trips according to the regions of the New Your city
